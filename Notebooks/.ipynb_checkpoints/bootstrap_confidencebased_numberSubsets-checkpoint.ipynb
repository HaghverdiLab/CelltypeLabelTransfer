# %%
library(ggplot2)
library(dplyr)

get_combinations <- function(files, size, seed){
    set.seed(seed)
    return(sample(files, size = size))
}

translate <- function(vector){
    vector <- stringr::str_replace_all(vector, "\\.\\.", "+ ")
    vector <- stringr::str_replace_all(vector, "\\.", " ")
    return(vector)
}

readSeurat <- function(file, cutoff=NULL){
    seurat <- read.csv(file, sep="\t")
    seurat$prediction.score.max <- NULL
    seurat <- seurat[, stringr::str_detect(colnames(seurat), "prediction.score.")]
    colnames(seurat) <- stringr::str_replace(colnames(seurat), "prediction.score.", "")
    colnames(seurat) <- translate(colnames(seurat))
    seurat[is.na(seurat)] <- 0
    if(!is.null(cutoff)) seurat[seurat < cutoff]<- 0
    
    return(seurat)
}

readSCN <- function(file, cutoff=NULL){
    scn <- read.csv(file, sep="\t")
    rownames(scn) <- scn$id 
    scn <- scn[, !colnames(scn) %in% c("id", "predicted", "nGene", "nUMI", "percent.mito",
                                       "Cluster", "class_", "Experiment", "Method",
                                       "prediction.match")]
    colnames(scn) <- translate(colnames(scn))
    scn[is.na(scn)] <- 0
    if(!is.null(cutoff)) scn[scn < cutoff]<- 0
    return(as.data.frame(scn))
}

readSingleR <- function(file, cutoff=NULL){
    singler <- read.csv(file, sep="\t")
    rownames(singler) <- singler$id 
    
    singler <- singler[, stringr::str_detect(colnames(singler), "scores.")]
    singler <- singler[, !stringr::str_detect(colnames(singler), "tuning")]
    colnames(singler) <- stringr::str_replace(colnames(singler), "scores.", "")
    colnames(singler) <- translate(colnames(singler))
    singler[is.na(singler)] <- 0
    if(!is.null(cutoff)) singler[singler < cutoff]<- 0
    return(singler)
}

readItclust <- function(file, cutoff=NULL){

    itclust <- read.csv(paste(sep="/", file, "results/clustering_prob.csv"))
    ids <- read.csv(paste(sep="/", file, "results/celltype_assignment.txt"), header=F)
    rownames(itclust) <- itclust$X
    itclust$X <- NULL

    ids[c("x", 'Cluster', 'x', "confidence", "x", "x", "type")] <-  stringr::str_split_fixed(ids$V1, ' ', 7)
    ids$type <- unlist(lapply(ids$type, function(type) substr(type, 1, nchar(type)-5)))
    ids$Cluster <- paste0("cluster", ids$Cluster)

    colnames(itclust) <- ids$type[ids$Cluster ==colnames(itclust)]
    itclust[is.na(itclust)] <- 0
     if(!is.null(cutoff)) itclust[itclust < cutoff]<- 0
    return(itclust)

}
                              
filter_set<- function(set, cutoff=NULL){
    set[is.na(set)] <- 0
    print(apply(set,1, max))
    print(apply(set,1, min))
    if(!is.null(cutoff)) set[set < cutoff]<- 0

    #getHeatmap(set)
   
    return(set)
} 
                              
get_binary_prediction <- function(set){
    predictions <-  apply(set, 1, which.max)
    predictions <- colnames(set)[predictions]
    names(predictions) <- rownames(set)
    return(predictions)
}

summarize_binary_prediction <- function(set){
   x <- which.max(table(set))
   return(set[x]) 
}
                              
get_predicton <- function(sets, combinations, method, set, cutoff=NULL){
    nr_sets <- length(combinations)
    print(combinations)
    print(nr_sets)
    subsets <- sets[names(sets) %in% combinations]

    prediction <- sapply(subsets, function(set) get_binary_prediction(set)) 
    prediction_binary <- apply(prediction, 1, summarize_binary_prediction)
                         
    combs <- Reduce('+', subsets)
    combs <- combs / nr_sets
    prediction <- apply(combs, 1, which.max)
    prediction <- colnames(combs)[prediction]
    confidence <- apply(combs, 1, max)

    df <- data.frame(id=rownames(combs), prediction_confidence=prediction, method=method, set=set,
                     confidence = confidence,prediction_binary = prediction_binary, size=nr_sets ) 
    return(df)
}
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
files <- list.files("../Data/Predictions/ItClust/", pattern = "PBMC10x_100_")
sizes=c(10,20,50,100,200)
cutoff = 0.3
sequence <- seq(1,20,1)
combinations <- unlist(lapply(sizes, function(size)lapply(sequence, function(seed) get_combinations(files, size, seed))), recursive = F)
options(repr.plot.width=10, repr.plot.height=15)
print(head(combinations))
# Out:
# [[1]]
#  [1] "PBMC10x_100_249" "PBMC10x_100_214" "PBMC10x_100_71"  "PBMC10x_100_267"
#  [5] "PBMC10x_100_175" "PBMC10x_100_78"  "PBMC10x_100_65"  "PBMC10x_100_17"
#  [9] "PBMC10x_100_290" "PBMC10x_100_131"
#
# [[2]]
#  [1] "PBMC10x_100_277" "PBMC10x_100_64"  "PBMC10x_100_74"  "PBMC10x_100_282"
#  [5] "PBMC10x_100_259" "PBMC10x_100_166" "PBMC10x_100_216" "PBMC10x_100_155"
#  [9] "PBMC10x_100_220" "PBMC10x_100_36"
#
# [[3]]
#  [1] "PBMC10x_100_63"  "PBMC10x_100_266" "PBMC10x_100_224" "PBMC10x_100_130"
#  [5] "PBMC10x_100_98"  "PBMC10x_100_77"  "PBMC10x_100_263" "PBMC10x_100_25"
#  [9] "PBMC10x_100_141" "PBMC10x_100_192"
#
# [[4]]
#  [1] "PBMC10x_100_166" "PBMC10x_100_61"  "PBMC10x_100_162" "PBMC10x_100_253"
#  [5] "PBMC10x_100_49"  "PBMC10x_100_266" "PBMC10x_100_154" "PBMC10x_100_190"
#  [9] "PBMC10x_100_215" "PBMC10x_100_235"
#
# [[5]]
#  [1] "PBMC10x_100_265" "PBMC10x_100_285" "PBMC10x_100_281" "PBMC10x_100_96"
#  [5] "PBMC10x_100_290" "PBMC10x_100_299" "PBMC10x_100_162" "PBMC10x_100_112"
#  [9] "PBMC10x_100_213" "PBMC10x_100_122"
#
# [[6]]
#  [1] "PBMC10x_100_107" "PBMC10x_100_264" "PBMC10x_100_189" "PBMC10x_100_207"
#  [5] "PBMC10x_100_215" "PBMC10x_100_273" "PBMC10x_100_208" "PBMC10x_100_187"
#  [9] "PBMC10x_100_83"  "PBMC10x_100_232"

# %%
hist(unlist(lapply(combinations, function(c) length(c))))
# Out:
# Plot with title “Histogram of unlist(lapply(combinations, function(c) length(c)))”

# %%
files_seurat <- lapply(files, function(file) list.files("../Data/Predictions/Seurat/",
                                                        pattern = paste0(file, "_predictions.txt"),
                                                        full.names = T))
                  
sets_seurat  <- lapply(files_seurat, function(file) readSeurat(file, cutoff))
names(sets_seurat)<- files
  
seurat_pred <- do.call(rbind,lapply(sequence, function(seq) get_predicton(sets_seurat,
                                                                       unlist(combinations[seq]),
                                                                       "Seurat", seq)))

seurat_pred[1:5,]
# Out:
#                        id                     prediction_confidence method set
# pbmc2_Celseq2_1_ACGTAC pbmc2_Celseq2_1_ACGTAC Cytotoxic T cell      Seurat 1
# pbmc2_Celseq2_1_ACTCTG pbmc2_Celseq2_1_ACTCTG CD4+ T cell           Seurat 1
# pbmc2_Celseq2_1_AGACCA pbmc2_Celseq2_1_AGACCA CD16+ monocyte        Seurat 1
# pbmc2_Celseq2_1_AGGACA pbmc2_Celseq2_1_AGGACA Cytotoxic T cell      Seurat 1
# pbmc2_Celseq2_1_AGTGTC pbmc2_Celseq2_1_AGTGTC Cytotoxic T cell      Seurat 1
#                        confidence prediction_binary   size
# pbmc2_Celseq2_1_ACGTAC 0.5359130  Natural killer cell 10
# pbmc2_Celseq2_1_ACTCTG 0.4130227  CD4+ T cell         10
# pbmc2_Celseq2_1_AGACCA 0.4586823  CD4+ T cell         10
# pbmc2_Celseq2_1_AGGACA 0.4918110  Natural killer cell 10
# pbmc2_Celseq2_1_AGTGTC 0.5510700  Natural killer cell 10

# %%
files_scn <- lapply(files, function(file) list.files("../Data/Predictions/SCN/",
                                                     pattern = paste0(file, ".txt"),
                                                     full.names = T))
sets_scn  <- lapply(files_scn, function(file) readSCN(file, cutoff))
names(sets_scn)<- files
scn_pred <- do.call(rbind,lapply(sequence, function(seq) get_predicton(sets_scn,
                                                                       unlist(combinations[seq]),
                                                                       "SCN", seq)))

head(scn_pred)
# Out:
#                               id
# pbmc2_10X_V2_AAACCTGAGATGGGTC pbmc2_10X_V2_AAACCTGAGATGGGTC
# pbmc2_10X_V2_AAACCTGAGCGTAATA pbmc2_10X_V2_AAACCTGAGCGTAATA
# pbmc2_10X_V2_AAACCTGAGCTAGGCA pbmc2_10X_V2_AAACCTGAGCTAGGCA
# pbmc2_10X_V2_AAACCTGAGGGTCTCC pbmc2_10X_V2_AAACCTGAGGGTCTCC
# pbmc2_10X_V2_AAACCTGGTCCGAACC pbmc2_10X_V2_AAACCTGGTCCGAACC
# pbmc2_10X_V2_AAACCTGTCGTCCGTT pbmc2_10X_V2_AAACCTGTCGTCCGTT
#                               prediction_confidence method set confidence
# pbmc2_10X_V2_AAACCTGAGATGGGTC B cell                SCN    1   0.9823
# pbmc2_10X_V2_AAACCTGAGCGTAATA B cell                SCN    1   0.9920
# pbmc2_10X_V2_AAACCTGAGCTAGGCA Cytotoxic T cell      SCN    1   0.3588
# pbmc2_10X_V2_AAACCTGAGGGTCTCC Dendritic cell        SCN    1   0.7568
# pbmc2_10X_V2_AAACCTGGTCCGAACC CD4+ T cell           SCN    1   0.7274
# pbmc2_10X_V2_AAACCTGTCGTCCGTT CD4+ T cell           SCN    1   0.5964
#                               prediction_binary size
# pbmc2_10X_V2_AAACCTGAGATGGGTC B cell            10
# pbmc2_10X_V2_AAACCTGAGCGTAATA B cell            10
# pbmc2_10X_V2_AAACCTGAGCTAGGCA Cytotoxic T cell  10
# pbmc2_10X_V2_AAACCTGAGGGTCTCC Dendritic cell    10
# pbmc2_10X_V2_AAACCTGGTCCGAACC CD4+ T cell       10
# pbmc2_10X_V2_AAACCTGTCGTCCGTT CD4+ T cell       10

# %%
files_singler <- lapply(files, function(file) list.files("../Data/Predictions/SingleR//",
                                                         pattern = paste0(file, ".txt"), 
                                                         full.names = T))
sets_singler  <- lapply(files_singler, function(file) readSingleR(file, cutoff))
names(sets_singler )<- files
singler_pred <- do.call(rbind,lapply(sequence, function(seq) get_predicton(sets_singler,
                                                                       unlist(combinations[seq]),
                                                                       "SingleR", seq)))
head(singler_pred)
# Out:
#                               id
# pbmc2_10X_V2_AAACCTGAGATGGGTC pbmc2_10X_V2_AAACCTGAGATGGGTC
# pbmc2_10X_V2_AAACCTGAGCGTAATA pbmc2_10X_V2_AAACCTGAGCGTAATA
# pbmc2_10X_V2_AAACCTGAGCTAGGCA pbmc2_10X_V2_AAACCTGAGCTAGGCA
# pbmc2_10X_V2_AAACCTGAGGGTCTCC pbmc2_10X_V2_AAACCTGAGGGTCTCC
# pbmc2_10X_V2_AAACCTGGTCCGAACC pbmc2_10X_V2_AAACCTGGTCCGAACC
# pbmc2_10X_V2_AAACCTGTCGTCCGTT pbmc2_10X_V2_AAACCTGTCGTCCGTT
#                               prediction_confidence method  set confidence
# pbmc2_10X_V2_AAACCTGAGATGGGTC B cell                SingleR 1   0.8446583
# pbmc2_10X_V2_AAACCTGAGCGTAATA B cell                SingleR 1   0.8656035
# pbmc2_10X_V2_AAACCTGAGCTAGGCA Natural killer cell   SingleR 1   0.8344543
# pbmc2_10X_V2_AAACCTGAGGGTCTCC Dendritic cell        SingleR 1   0.8759608
# pbmc2_10X_V2_AAACCTGGTCCGAACC CD4+ T cell           SingleR 1   0.8543692
# pbmc2_10X_V2_AAACCTGTCGTCCGTT CD4+ T cell           SingleR 1   0.8001878
#                               prediction_binary   size
# pbmc2_10X_V2_AAACCTGAGATGGGTC B cell              10
# pbmc2_10X_V2_AAACCTGAGCGTAATA B cell              10
# pbmc2_10X_V2_AAACCTGAGCTAGGCA Natural killer cell 10
# pbmc2_10X_V2_AAACCTGAGGGTCTCC Dendritic cell      10
# pbmc2_10X_V2_AAACCTGGTCCGAACC CD4+ T cell         10
# pbmc2_10X_V2_AAACCTGTCGTCCGTT CD4+ T cell         10

# %%
files_itclust <- paste0("../Data/Predictions/ItClust/", files)
sets_itclust  <- lapply(files_itclust, function(file) readItclust(file, cutoff))
names(sets_itclust )<- files
itclust_pred <- do.call(rbind,lapply(sequence, function(seq) get_predicton(sets_itclust,
                                                                       unlist(combinations[seq]),
                                                                       "ItClust", seq)))
itclust_pred$id <- stringr::str_replace(itclust_pred$id, "-target", "")
head(itclust_pred)
# Out:
#                               id                     prediction_confidence
# pbmc2_Celseq2_1_ACTCAC-target pbmc2_Celseq2_1_ACTCAC B cell
# pbmc2_Celseq2_1_ACTCGA-target pbmc2_Celseq2_1_ACTCGA B cell
# pbmc2_Celseq2_1_CAACCA-target pbmc2_Celseq2_1_CAACCA B cell
# pbmc2_Celseq2_1_CACTAG-target pbmc2_Celseq2_1_CACTAG B cell
# pbmc2_Celseq2_1_CACTTC-target pbmc2_Celseq2_1_CACTTC B cell
# pbmc2_Celseq2_1_CATGAG-target pbmc2_Celseq2_1_CATGAG B cell
#                               method  set confidence prediction_binary size
# pbmc2_Celseq2_1_ACTCAC-target ItClust 1   0.9196374  B cell            10
# pbmc2_Celseq2_1_ACTCGA-target ItClust 1   0.9152113  B cell            10
# pbmc2_Celseq2_1_CAACCA-target ItClust 1   0.9218095  B cell            10
# pbmc2_Celseq2_1_CACTAG-target ItClust 1   0.9172924  B cell            10
# pbmc2_Celseq2_1_CACTTC-target ItClust 1   0.9103373  B cell            10
# pbmc2_Celseq2_1_CATGAG-target ItClust 1   0.9103213  B cell            10

# %%
ref <- read.csv("../Data/Fulldata/PBMC_Query/meta.csv")
data <- read.csv("../Results/Files/results_PBMC.csv")
celltypes = c("Cytotoxic T cell", "CD4+ T cell", "CD14+ monocyte", "B cell", "Megakaryocyte",
              "Natural killer cell", "CD16+ monocyte", "Dendritic cell", "Plasmacytoid dendritic cell")
x <- reshape2::melt(data,  id.vars =c("id"),value.name = "Prediction")
x[c('Reference', 'method', "Size", "Set")] <- stringr::str_split_fixed(x$variable, '_', 4)
x <- merge(x, ref, by="id")

x$Prediction[x$Prediction =="Cytotoxic T"] <- "Cytotoxic T cell"
x$Prediction[x$Prediction == "B"] <- "B cell"
x$Prediction[x$Prediction == "CD4+ T"] <- "CD4+ T cell"
x$Prediction[x$Prediction == "Natural killer"] <- "Natural killer cell"
x$Prediction[x$Prediction == "Dendritic"] <- "Dendritic cell"
x$Prediction[x$Prediction == "Plasmacytoid dendritic"] <- "Plasmacytoid dendritic cell"
x$match_full <- x$Prediction == x$class_ 
query <- x[x$Size == 3090,]

head(query)
# Out:
#      id                            variable               Prediction Reference
# 1181 pbmc2_10X_V2_AAACCTGAGATGGGTC PBMC10x_Seurat_3090_0  B cell     PBMC10x
# 1636 pbmc2_10X_V2_AAACCTGAGATGGGTC PBMC10x_ItClust_3090_0 B cell     PBMC10x
# 3275 pbmc2_10X_V2_AAACCTGAGATGGGTC PBMC10x_SingleR_3090_0 B cell     PBMC10x
# 3459 pbmc2_10X_V2_AAACCTGAGATGGGTC PBMC10x_CellID_3090_0  B cell     PBMC10x
# 3869 pbmc2_10X_V2_AAACCTGAGATGGGTC PBMC10x_SCN_3090_0     B cell     PBMC10x
# 6375 pbmc2_10X_V2_AAACCTGAGCGTAATA PBMC10x_ItClust_3090_0 B cell     PBMC10x
#      method  Size Set nGene nUMI percent.mito Cluster class_ Experiment Method
# 1181 Seurat  3090 0   1044  2360 0.04194915   2       B cell pbmc2      10x
# 1636 ItClust 3090 0   1044  2360 0.04194915   2       B cell pbmc2      10x
# 3275 SingleR 3090 0   1044  2360 0.04194915   2       B cell pbmc2      10x
# 3459 CellID  3090 0   1044  2360 0.04194915   2       B cell pbmc2      10x
# 3869 SCN     3090 0   1044  2360 0.04194915   2       B cell pbmc2      10x
# 6375 ItClust 3090 0    803  1888 0.04131356   2       B cell pbmc2      10x
#      match_full
# 1181 TRUE
# 1636 TRUE
# 3275 TRUE
# 3459 TRUE
# 3869 TRUE
# 6375 TRUE

# %%
predictions <- do.call(rbind, list(seurat_pred, scn_pred, singler_pred, itclust_pred))

data <- merge(query[,c("id", "method", "match_full", "class_")], predictions, by=c("id", "method"))
data$match_confidence <- data$class_ == data$prediction_confidence
data$match_binary <- data$class_ == data$prediction_binary

summary <- data %>% 
           dplyr::group_by(method, class_, set, size) %>% 
dplyr::summarize(accuracy_confidence= mean(match_confidence),
                 accuracy_full=mean(match_full),
                 accuracy_binary=mean(match_binary),
                mean_confidence = mean(confidence)) 
print(head(summary))
# Out:
# `summarise()` has grouped output by 'method', 'class_', 'set'. You can override
# using the `.groups` argument.
# # A tibble: 6 × 8
# # Groups:   method, class_, set [6]
#   method  class_   set  size accuracy_confidence accuracy_full accurac…¹ mean_…²
#   <chr>   <chr>  <dbl> <int>               <dbl>         <dbl>     <dbl>   <dbl>
# 1 ItClust B cell     1    10               0.991         0.960     0.995   0.888
# 2 ItClust B cell     2    10               0.992         0.960     0.996   0.887
# 3 ItClust B cell     3    10               0.992         0.960     0.995   0.891
# 4 ItClust B cell     4    10               0.990         0.960     0.992   0.886
# 5 ItClust B cell     5    10               0.991         0.960     0.996   0.887
# 6 ItClust B cell     6    10               0.992         0.960     0.995   0.887
# # … with abbreviated variable names ¹​accuracy_binary, ²​mean_confidence

# %%
options(repr.plot.width=15, repr.plot.height=5)
celltypes = c("Cytotoxic T cell", "CD4+ T cell", "CD14+ monocyte", "B cell",
              "Megakaryocyte", "Natural killer cell", "CD16+ monocyte",
              "Dendritic cell", "Plasmacytoid dendritic cell")

summary$class_ <- factor(summary$class_, levels=celltypes)

# %%
summary$dif_con_full <- summary$accuracy_confidence - summary$accuracy_full
summary$dif_bin_full <- summary$accuracy_binary - summary$accuracy_full
summary$dif_con_bin <- summary$accuracy_confidence - summary$accuracy_binary
head(summary)
# Out:
#   method  class_ set size accuracy_confidence accuracy_full accuracy_binary
# 1 ItClust B cell 1   10   0.9910011           0.9595051     0.9947507
# 2 ItClust B cell 2   10   0.9921260           0.9595051     0.9955006
# 3 ItClust B cell 3   10   0.9921260           0.9595051     0.9947507
# 4 ItClust B cell 4   10   0.9902512           0.9595051     0.9921260
# 5 ItClust B cell 5   10   0.9913761           0.9595051     0.9955006
# 6 ItClust B cell 6   10   0.9917510           0.9595051     0.9947507
#   mean_confidence dif_con_full dif_bin_full dif_con_bin
# 1 0.8881138       0.03149606   0.03524559   -0.003749531
# 2 0.8872034       0.03262092   0.03599550   -0.003374578
# 3 0.8914894       0.03262092   0.03524559   -0.002624672
# 4 0.8862558       0.03074616   0.03262092   -0.001874766
# 5 0.8872956       0.03187102   0.03599550   -0.004124484
# 6 0.8872334       0.03224597   0.03524559   -0.002999625

# %%
ggplot(summary, aes(class_, dif_bin_full, fill=class_)) + geom_violin(alpha=0.2) + geom_boxplot(width=0.1)+ theme_bw()+
facet_grid(cols =vars(method), rows=vars(size))+geom_hline(yintercept = 0, linetype="dashed")+ ylim(-1, 1)+
theme(axis.text.x = element_text(angle=25, hjust = 1))
# Out:
# plot without title

# %%
ggplot(summary, aes(class_, dif_con_full, fill=class_)) + geom_violin() + geom_boxplot(width=0.1) + theme_bw()+
facet_grid(cols =vars(method), rows=vars(size))+geom_hline(yintercept = 0, linetype="dashed")+ ylim(-1, 1)+
theme(axis.text.x = element_text(angle=25, hjust = 1))
# Out:
# plot without title

# %%
ggplot(summary, aes(class_, dif_con_bin, fill=class_)) + geom_violin(alpha=0.2) + geom_boxplot(width=0.1)+
theme_bw()+
facet_grid(cols =vars(method), rows=vars(size))+geom_hline(yintercept = 0, linetype="dashed")+ ylim(-1, 1)+
theme(axis.text.x = element_text(angle=25, hjust = 1))
# Out:
# plot without title

# %%
table(seurat_pred$size)
# Out:
#     10
# 218200
